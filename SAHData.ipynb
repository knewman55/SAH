# %%
import somadata
from scipy.stats import ttest_ind
from collections import Counter
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
from io import StringIO
print("done")
# Out:
# done

# %%
#adat file that has been plate scaled and hybrid normalized (not median normalized)
adat = somadata.read_adat('/Users/kenny/Documents/Medical School/Research/MSSRP/Data/UFL-17-005DataFromSoma-Jenna-SerumConbine/UFL-17-005.hybNorm.plateScale.20180411.adat')
type(adat)
# Out:
# /Users/kenny/opt/anaconda3/lib/python3.9/site-packages/somadata/io/adat/file.py:125: UserWarning: V3 style seqIds (i.e., 12345-6_7). Converting to V4 Style. The adat file writer has an option to write using the V3 style
#   warnings.warn(
# somadata.adat.Adat

# %%
adat.columns
# Out:
# MultiIndex([(  '10336-3', '3', 'SL019100', ...),
#             ( '10337-83', '3', 'SL007136', ...),
#             ( '10339-48', '3', 'SL001731', ...),
#             ( '10342-55', '3', 'SL019096', ...),
#             ('10344-334', '3', 'SL005173', ...),
#             (  '10346-5', '3', 'SL007221', ...),
#             ( '10351-51', '3', 'SL007108', ...),
#             ( '10356-21', '3', 'SL000455', ...),
#             ( '10358-33', '3', 'SL003755', ...),
#             ( '10361-25', '3', 'SL014684', ...),
#             ...
#             (   '9199-6', '3', 'SL018946', ...),
#             (  '9201-13', '3', 'SL004811', ...),
#             ( '9202-309', '3', 'SL008113', ...),
#             (  '9204-33', '3', 'SL009210', ...),
#             (  '9207-60', '3', 'SL018887', ...),
#             (  '9211-19', '3', 'SL003066', ...),
#             (  '9212-22', '3', 'SL008381', ...),
#             (  '9213-24', '3', 'SL018900', ...),
#             ( '9215-117', '3', 'SL018947', ...),
#             ( '9216-100', '3', 'SL009948', ...)],
#            names=['SeqId', 'SeqIdVersion', 'SomaId', 'TargetFullName', 'Target', 'UniProt', 'EntrezGeneID', 'EntrezGeneSymbol', 'Organism', 'Units', 'Type', 'Dilution', 'PlateScale_Reference'], length=1317)

# %%
#Loading in the SomaScan Master sheet. Will need to change path on personal computer
vaso_data = pd.read_excel("/Users/kenny/Documents/Medical School/Research/MSSRP/SomaScan_Master_Sheet_07.10.2024.xlsx", skiprows=4, sheet_name = "Serum Samples")
vaso_data = vaso_data[['SampleId', 'Clinical Vasospasm/DIND (1=yes, 0=no)']]
vaso_data
# Out:
#                                              SampleId  \
# 0                                          SB44-2-S06
# 1                                              180472
# 2                                              145052
# 3                                              135203
# 4                                              177450
# ..                                                ...
# 71                                         S-1-103006
# 72                                                NaN
# 73                                                NaN
# 74  Note: 12 samples on pilot serum plate should n...
# 75  Note: samples highlighted are not to be includ...
#
#    Clinical Vasospasm/DIND (1=yes, 0=no)
# 0                                      1
# 1                                      0
# 2                                      0
# 3                                      0
# 4                                      0
# ..                                   ...
# 71                        Pilot Control
# 72                                   NaN
# 73
# 74
# 75                                   NaN
#
# [76 rows x 2 columns]

# %%
#Merging vasospasm data with SAH adat file. Source code derived from Soma Logic Canopy GitHub
#Vasospasm metadata loaded, but actual data not merged currently

# The arguments are `axis` 0 for row metadata, 1 for column metadata, `name` the name of the new index,
#`key_meta_name` the nameo of the axis used to match the keys. `values_dict` the dictionary containing the new data
new_meta_adat = adat.insert_keyed_meta(0,'Clinical Vasospasm/DIND (1=yes, 0=no)', 'SampleId', 'vaso_data')
# this will produce a new Adat file with group data in the right most column of the index
new_meta_adat.index.to_frame(index=False).loc[0:6]
# Out:
#    PlateId   ScannerID PlatePosition       SlideId Subarray  \
# 0  Set 003  US83800208            H4  257711020969        8
# 1  Set 003  US83800208            H3  257711020968        8
# 2  Set 003  US83800208            H2  257711020967        8
# 3  Set 003  US83800208            H1  257711020962        8
# 4  Set 003  US83800208            G4  257711020969        7
# 5  Set 003  US83800208            G3  257711020968        7
# 6  Set 003  US83800208            G2  257711020967        7
#
#               SampleId  SampleType PercentDilution SampleMatrix  Barcode  ...  \
# 0               160384          QC              40           QC  160384C  ...
# 1         PHE-L Dichot      Sample              40                        ...
# 2          S-01-120710      Sample              40                        ...
# 3           S-1-082806      Sample              40                        ...
# 4  CAA Negative Dichot      Sample              40                        ...
# 5               160385  Calibrator              40   Calibrator  160385C  ...
# 6               184277      Sample              40                        ...
#
#         SsfExtId SampleGroup SiteId TubeUniqueID HybControlNormScale RowCheck  \
# 0  2577110209698                                               1.125     PASS
# 1      EID323094                                               0.997     PASS
# 2      EID323088                                               1.003     PASS
# 3      EID323082                                               1.046     PASS
# 4      EID323100                                               1.075     PASS
# 5  2577110209687                                               0.991     PASS
# 6      EID323087                                               0.963     PASS
#
#   NormScale_1 NormScale_40 NormScale_0_005  \
# 0       1.000        1.000           1.000
# 1       1.446        1.511           1.468
# 2       1.049        1.175           1.021
# 3       1.542        1.548           1.252
# 4       1.001        1.097           1.103
# 5       1.062        1.023           1.030
# 6       0.962        1.083           0.881
#
#   Clinical Vasospasm/DIND (1=yes, 0=no)
# 0
# 1
# 2
# 3
# 4
# 5
# 6
#
# [7 rows x 26 columns]

# %%
#Displaying adat file. Source code derived from Soma Logic Canopy GitHub

from IPython.display import HTML
#Display the first five rows and columns of the adat
HTML(adat.iloc[:10, :10].to_html())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th>SeqId</th>
#       <th>10336-3</th>
#       <th>10337-83</th>
#       <th>10339-48</th>
#       <th>10342-55</th>
#       <th>10344-334</th>
#       <th>10346-5</th>
#       <th>10351-51</th>
#       <th>10356-21</th>
#       <th>10358-33</th>
#       <th>10361-25</th>
#     </tr>
#     <tr>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th>SeqIdVersion</th>
#       <th>3</th>
#       <th>3</th>
#       <th>3</th>
#       <th>3</th>
#       <th>3</th>
#       <th>3</th>
#       <th>3</th>
#       <th>3</th>
#       <th>3</th>
#       <th>3</th>
#     </tr>
#     <tr>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th>SomaId</th>
#       <th>SL019100</th>
#       <th>SL007136</th>
#       <th>SL001731</th>
#       <th>SL019096</th>
#       <th>SL005173</th>
#       <th>SL007221</th>
#       <th>SL007108</th>
#       <th>SL000455</th>
#       <th>SL003755</th>
#       <th>SL014684</th>
#     </tr>
#     <tr>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th>TargetFullName</th>
#       <th>E3 ubiquitin-protein ligase CHIP</th>
#       <th>CCAAT/enhancer-binding protein beta</th>
#       <th>Gamma-enolase</th>
#       <th>E3 SUMO-protein ligase PIAS4</th>
#       <th>Interleukin-10 receptor subunit alpha</th>
#       <th>Signal transducer and activator of transcription 3</th>
#       <th>Interferon regulatory factor 1</th>
#       <th>Transcription factor AP-1</th>
#       <th>Induced myeloid leukemia cell differentiation protein Mcl-1</th>
#       <th>2'-5'-oligoadenylate synthase 1</th>
#     </tr>
#     <tr>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th>Target</th>
#       <th>CHIP</th>
#       <th>CEBPB</th>
#       <th>NSE</th>
#       <th>PIAS4</th>
#       <th>IL-10 Ra</th>
#       <th>STAT3</th>
#       <th>IRF1</th>
#       <th>c-Jun</th>
#       <th>Mcl-1</th>
#       <th>OAS1</th>
#     </tr>
#     <tr>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th>UniProt</th>
#       <th>Q9UNE7</th>
#       <th>P17676</th>
#       <th>P09104</th>
#       <th>Q8N2W9</th>
#       <th>Q13651</th>
#       <th>P40763</th>
#       <th>P10914</th>
#       <th>P05412</th>
#       <th>Q07820</th>
#       <th>P00973</th>
#     </tr>
#     <tr>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th>EntrezGeneID</th>
#       <th>10273</th>
#       <th>1051</th>
#       <th>2026</th>
#       <th>51588</th>
#       <th>3587</th>
#       <th>6774</th>
#       <th>3659</th>
#       <th>3725</th>
#       <th>4170</th>
#       <th>4938</th>
#     </tr>
#     <tr>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th>EntrezGeneSymbol</th>
#       <th>STUB1</th>
#       <th>CEBPB</th>
#       <th>ENO2</th>
#       <th>PIAS4</th>
#       <th>IL10RA</th>
#       <th>STAT3</th>
#       <th>IRF1</th>
#       <th>JUN</th>
#       <th>MCL1</th>
#       <th>OAS1</th>
#     </tr>
#     <tr>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th>Organism</th>
#       <th>Human</th>
#       <th>Human</th>
#       <th>Human</th>
#       <th>Human</th>
#       <th>Human</th>
#       <th>Human</th>
#       <th>Human</th>
#       <th>Human</th>
#       <th>Human</th>
#       <th>Human</th>
#     </tr>
#     <tr>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th>Units</th>
#       <th>RFU</th>
#       <th>RFU</th>
#       <th>RFU</th>
#       <th>RFU</th>
#       <th>RFU</th>
#       <th>RFU</th>
#       <th>RFU</th>
#       <th>RFU</th>
#       <th>RFU</th>
#       <th>RFU</th>
#     </tr>
#     <tr>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th>Type</th>
#       <th>Protein</th>
#       <th>Protein</th>
#       <th>Protein</th>
#       <th>Protein</th>
#       <th>Protein</th>
#       <th>Protein</th>
#       <th>Protein</th>
#       <th>Protein</th>
#       <th>Protein</th>
#       <th>Protein</th>
#     </tr>
#     <tr>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th>Dilution</th>
#       <th>40</th>
#       <th>40</th>
#       <th>1</th>
#       <th>40</th>
#       <th>1</th>
#       <th>1</th>
#       <th>1</th>
#       <th>40</th>
#       <th>40</th>
#       <th>40</th>
#     </tr>
#     <tr>
#       <th></th>
#       <

# %%
#Check to see number of patients vs controls/calibrators
Counter(adat.index.get_level_values('SampleType'))
# Out:
# Counter({'QC': 9, 'Sample': 72, 'Calibrator': 15})

# %%
filtered_transformed_data = (
    adat
        .pick_on_meta(axis=0, name='SampleType', values=['Sample'])  # rm control samples
        .apply(np.log10)                                             # log10-transform
)

# %%
# One-sample t-tests
p_values = []
for protein in patient_data.columns:
    stat, p_value = ttest_1samp(patient_data[protein], reference_medians[protein])
    p_values.append(p_value)

# %%
#Plate scale that has been plate scaled, hybrid normalized, and median normalized (used for QC)
adat2 = somadata.read_adat('/Users/kenny/Documents/Medical School/Research/MSSRP/Data/UFL-17-005DataFromSoma-Jenna-SerumConbine/UFL-17-005.hybNorm.plateScale.medNorm.20180411.adat')

#Display the first ten rows and columns of the adat
HTML(adat2.iloc[:10, :10].to_html())
# Out:
# /Users/kenny/opt/anaconda3/lib/python3.9/site-packages/somadata/io/adat/file.py:125: UserWarning: V3 style seqIds (i.e., 12345-6_7). Converting to V4 Style. The adat file writer has an option to write using the V3 style
#   warnings.warn(
# <table border="1" class="dataframe">
#   <thead>
#     <tr>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th>SeqId</th>
#       <th>10336-3</th>
#       <th>10337-83</th>
#       <th>10339-48</th>
#       <th>10342-55</th>
#       <th>10344-334</th>
#       <th>10346-5</th>
#       <th>10351-51</th>
#       <th>10356-21</th>
#       <th>10358-33</th>
#       <th>10361-25</th>
#     </tr>
#     <tr>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th>SeqIdVersion</th>
#       <th>3</th>
#       <th>3</th>
#       <th>3</th>
#       <th>3</th>
#       <th>3</th>
#       <th>3</th>
#       <th>3</th>
#       <th>3</th>
#       <th>3</th>
#       <th>3</th>
#     </tr>
#     <tr>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th>SomaId</th>
#       <th>SL019100</th>
#       <th>SL007136</th>
#       <th>SL001731</th>
#       <th>SL019096</th>
#       <th>SL005173</th>
#       <th>SL007221</th>
#       <th>SL007108</th>
#       <th>SL000455</th>
#       <th>SL003755</th>
#       <th>SL014684</th>
#     </tr>
#     <tr>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th>TargetFullName</th>
#       <th>E3 ubiquitin-protein ligase CHIP</th>
#       <th>CCAAT/enhancer-binding protein beta</th>
#       <th>Gamma-enolase</th>
#       <th>E3 SUMO-protein ligase PIAS4</th>
#       <th>Interleukin-10 receptor subunit alpha</th>
#       <th>Signal transducer and activator of transcription 3</th>
#       <th>Interferon regulatory factor 1</th>
#       <th>Transcription factor AP-1</th>
#       <th>Induced myeloid leukemia cell differentiation protein Mcl-1</th>
#       <th>2'-5'-oligoadenylate synthase 1</th>
#     </tr>
#     <tr>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th>Target</th>
#       <th>CHIP</th>
#       <th>CEBPB</th>
#       <th>NSE</th>
#       <th>PIAS4</th>
#       <th>IL-10 Ra</th>
#       <th>STAT3</th>
#       <th>IRF1</th>
#       <th>c-Jun</th>
#       <th>Mcl-1</th>
#       <th>OAS1</th>
#     </tr>
#     <tr>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th>UniProt</th>
#       <th>Q9UNE7</th>
#       <th>P17676</th>
#       <th>P09104</th>
#       <th>Q8N2W9</th>
#       <th>Q13651</th>
#       <th>P40763</th>
#       <th>P10914</th>
#       <th>P05412</th>
#       <th>Q07820</th>
#       <th>P00973</th>
#     </tr>
#     <tr>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th>EntrezGeneID</th>
#       <th>10273</th>
#       <th>1051</th>
#       <th>2026</th>
#       <th>51588</th>
#       <th>3587</th>
#       <th>6774</th>
#       <th>3659</th>
#       <th>3725</th>
#       <th>4170</th>
#       <th>4938</th>
#     </tr>
#     <tr>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th>EntrezGeneSymbol</th>
#       <th>STUB1</th>
#       <th>CEBPB</th>
#       <th>ENO2</th>
#       <th>PIAS4</th>
#       <th>IL10RA</th>
#       <th>STAT3</th>
#       <th>IRF1</th>
#       <th>JUN</th>
#       <th>MCL1</th>
#       <th>OAS1</th>
#     </tr>
#     <tr>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th>Organism</th>
#       <th>Human</th>
#       <th>Human</th>
#       <th>Human</th>
#       <th>Human</th>
#       <th>Human</th>
#       <th>Human</th>
#       <th>Human</th>
#       <th>Human</th>
#       <th>Human</th>
#       <th>Human</th>
#     </tr>
#     <tr>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th>Units</th>
#       <th>RFU</th>
#       <th>RFU</th>
#       <th>RFU</th>
#       <th>RFU</th>
#       <th>RFU</th>
#       <th>RFU</th>
#       <th>RFU</th>
#       <th>RFU</th>
#       <th>RFU</th>
#       <th>RFU</th>
#     </tr>
#     <tr>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th>Type</th>
#       <th>Protein</th>
#       <th>Protein</th>
#       <th>Protein</th>
#       <th>Protein</th>
#       <th>Protein</th>
#       <th>Protein</th>
#       <th>Protein</th>
#       <th>Protein</th>
#       <th>Protein</th>
#       <th>Protein</th>
#     </tr>
#     <tr>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th>Dilution</th>
#       <th>40</th>
#       <th>40</th>
#       <th>1</th>
#       <th>40</th>
#       <th>1</th>
#       <th>1</th>
#       <th>1</th>
#       <th>40</th>
#       <th>40</th>
#       <th>40</th>
#     </tr>
#     <tr>
#       <th></th>
#       <
